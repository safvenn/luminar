# %% [markdown]
# 1.Row count

# %%
import pandas as pd

df= pd.read_csv(r'C:\Desktop\luminar\Eda1\pandas1\files\customer5_windows.csv')

df.shape[0]
# Out:
# (73, 7)

# %% [markdown]
# 2.find total number of missing values

# %%
sum(df.isna().sum())
# Out:
# 0

# %% [markdown]
# 3.each profession count [desc]

# %%
df.groupby('prof')['prof'].count().sort_values(ascending=False)
# Out:
# prof
# Musician                           5
# Childcare worker                   5
# Doctor                             4
# Civil engineer                     3
# Writer                             3
# Real estate agent                  3
# Lawyer                             3
# Carpenter                          3
# Economist                          3
# Engineering technician             3
# Computer support specialist        3
# Artist                             2
# Secretary                          2
# Pilot                              2
# Agricultural and food scientist    2
# Police officer                     2
# Computer hardware engineer         2
# Firefighter                        2
# Teacher                            2
# Athlete                            2
# Reporter                           2
# Actor                              1
# Accountant                         1
# Human resources assistant          1
# Computer software engineer         1
# ...

# %% [markdown]
# 4.india work,each prof count [desc]

# %%
df[df['loc']=='india'].groupby('prof')['prof'].count().sort_values(ascending=False)
# Out:
# prof
# Carpenter                      3
# Musician                       3
# Writer                         2
# Accountant                     1
# Computer support specialist    1
# Dancer                         1
# Artist                         1
# Childcare worker               1
# Engineering technician         1
# Doctor                         1
# Financial analyst              1
# Environmental scientist        1
# Lawyer                         1
# Pharmacist                     1
# Pilot                          1
# Therapist                      1
# Name: prof, dtype: int64

# %% [markdown]
# 5.each profession maximum salry

# %%
df.groupby('prof')['salary'].max().sort_values(ascending=False)
# Out:
# prof
# Secretary                          10000000
# Recreation and fitness worker       7896254
# Artist                              4500000
# Social worker                       2250000
# Computer support specialist         1700000
# Childcare worker                    1700000
# Economist                           1500000
# Athlete                              960000
# Actor                                650000
# Veterinarian                         500000
# Lawyer                               500000
# Doctor                               500000
# Agricultural and food scientist      470000
# Real estate agent                    456987
# Civil engineer                       450000
# Writer                               450000
# Teacher                              410000
# Carpenter                            400000
# Pilot                                369000
# Judge                                258974
# Musician                             159879
# ...

# %% [markdown]
# 6.each prof minimum age  [asc]

# %%
df.groupby('prof')['salary'].min().sort_values()
# Out:
# prof
# Doctor                                3685
# Carpenter                            25000
# Engineering technician               25000
# Financial analyst                    25000
# Physicist                            25000
# Police officer                       25000
# Musician                             26000
# Civil engineer                       35000
# Pharmacist                           36000
# Reporter                             40000
# Human resources assistant            45000
# Lawyer                               45000
# Economist                            45000
# Pilot                                45000
# Writer                               45000
# Teacher                              45987
# Dancer                               50000
# Firefighter                          50000
# Childcare worker                     50000
# Computer hardware engineer           50000
# Environmental scientist              58789
# Agricultural and food scientist      65000
# ...

# %% [markdown]
# 7.uk work each profession total salry

# %%
df[df['loc']=='uk'].groupby('prof')['salary'].sum().sort_values(ascending=False)
# Out:
# prof
# Secretary                          10450000
# Artist                              4500000
# Social worker                       2250000
# Childcare worker                    1830000
# Economist                           1635000
# Civil engineer                       685000
# Actor                                650000
# Doctor                               625000
# Agricultural and food scientist      535000
# Lawyer                               500000
# Teacher                              455987
# Real estate agent                    410000
# Writer                               250000
# Reporter                             115000
# Engineering technician               100000
# Computer software engineer            85000
# Musician                              80000
# Photographer                          80000
# Computer hardware engineer            50000
# Firefighter                           50000
# Human resources assistant             45000
# ...

# %% [markdown]
# 8.each prof average salary [desc]

# %%
df.groupby('prof')['salary'].mean().sort_values(ascending=False)
# Out:
# prof
# Recreation and fitness worker      7.896254e+06
# Secretary                          5.225000e+06
# Artist                             2.644780e+06
# Social worker                      2.250000e+06
# Computer support specialist        7.579737e+05
# Athlete                            7.194810e+05
# Actor                              6.500000e+05
# Economist                          5.450000e+05
# Veterinarian                       5.000000e+05
# Childcare worker                   4.703970e+05
# Real estate agent                  2.889957e+05
# Agricultural and food scientist    2.675000e+05
# Judge                              2.589740e+05
# Writer                             2.483333e+05
# Civil engineer                     2.283333e+05
# Teacher                            2.279935e+05
# Pilot                              2.070000e+05
# Lawyer                             1.968933e+05
# Carpenter                          1.612630e+05
# ...

# %% [markdown]
# 9.each profession minimum salary [sal desc]

# %%
df.groupby('prof')['salary'].min().sort_values(ascending=False)
# Out:
# prof
# Recreation and fitness worker      7896254
# Social worker                      2250000
# Artist                              789560
# Actor                               650000
# Veterinarian                        500000
# Athlete                             478962
# Secretary                           450000
# Judge                               258974
# Real estate agent                   160000
# Accountant                           95000
# Computer support specialist          95000
# Therapist                            85000
# Computer software engineer           85000
# Photographer                         80000
# Agricultural and food scientist      65000
# Environmental scientist              58789
# Firefighter                          50000
# Dancer                               50000
# Computer hardware engineer           50000
# Childcare worker                     50000
# Teacher                              45987
# Lawyer                               45000
# ...

# %% [markdown]
# 10.india work , each profession average salary [desc]

# %%
df[df['loc']=='india'].groupby('prof')['salary'].mean().sort_values(ascending=False)
# Out:
# prof
# Artist                         789560.000000
# Writer                         247500.000000
# Carpenter                      161263.000000
# Accountant                      95000.000000
# Computer support specialist     95000.000000
# Therapist                       85000.000000
# Childcare worker                65000.000000
# Environmental scientist         58789.000000
# Musician                        58666.666667
# Engineering technician          55555.000000
# Dancer                          50000.000000
# Pilot                           45000.000000
# Lawyer                          45000.000000
# Pharmacist                      36000.000000
# Financial analyst               25000.000000
# Doctor                           3685.000000
# Name: salary, dtype: float64
