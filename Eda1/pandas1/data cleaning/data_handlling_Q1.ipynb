# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'/content/heart.csv')

# %% [markdown]
# find total row count

# %%
df.shape[0]
# Out:
# 1025

# %% [markdown]
# each target column count

# %%
df.groupby('target')['target'].count()
# Out:
# target
# 0    499
# 1    526
# Name: target, dtype: int64

# %% [markdown]
# separate x and y

# %%
y=df.iloc[:,-1]
x=df.iloc[:,:-1]
print(y)
print(x)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0     125.0   212    0      NaN    168.0      0      1.0
# 1      53    1   0     140.0   203    1      0.0    155.0      1      3.1
# 2      70    1   0     145.0   174    0      1.0    125.0      1      2.6
# 3      61    1   0     148.0   203    0      1.0      NaN      0      0.0
# 4      62    0   0     138.0   294    1      1.0    106.0      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1     140.0   221    0      1.0    164.0      1      0.0
# 1021   60    1   0     125.0   258    0      0.0    141.0      1      2.8
# 1022   47    1   0     110.0   275    0      0.0    118.0      1      1.0
# ...

# %% [markdown]
# display datatypes

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps    float64
# chol          int64
# fbs           int64
# restecg     float64
# thalach     float64
# exang         int64
# oldpeak     float64
# slope         int64
# ca          float64
# thal        float64
# target        int64
# dtype: object

# %% [markdown]
# find total nu of missing alues

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    1
# chol        0
# fbs         0
# restecg     1
# thalach     1
# exang       0
# oldpeak     0
# slope       0
# ca          2
# thal        1
# target      0
# dtype: int64

# %% [markdown]
# fill the missing value proper way

# %%
x=df['trestbps'].mode()[0]
df['trestbps'].fillna(x,inplace=True)
# Out:
# /tmp/ipykernel_5048/290927382.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['trestbps'].fillna(x,inplace=True)

# %%
x=df['restecg'].mode()[0]
df['restecg'].fillna(x,inplace=True)
# Out:
# /tmp/ipykernel_5048/1938559969.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['restecg'].fillna(x,inplace=True)

# %%
x=df['thalach'].mean()
df['thalach'].fillna(x,inplace=True)
# Out:
# /tmp/ipykernel_5048/1947547177.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['thalach'].fillna(x,inplace=True)

# %%
x=df['ca'].mode()[0]
df['ca'].fillna(x,inplace=True)
df.head(10)
# Out:
# /tmp/ipykernel_5048/589558053.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ca'].fillna(x,inplace=True)
#    age  sex  cp  trestbps  chol  fbs  restecg     thalach  exang  oldpeak  \
# 0   52    1   0     125.0   212    0      1.0  168.000000      0      1.0
# 1   53    1   0     140.0   203    1      0.0  155.000000      1      3.1
# 2   70    1   0     145.0   174    0      1.0  125.000000      1      2.6
# 3   61    1   0     148.0   203    0      1.0  149.102539      0      0.0
# ...

# %%
x=df['thal'].mode()[0]
df['thal'].fillna(x,inplace=True)
df.head(10)
# Out:
# /tmp/ipykernel_5048/3817911750.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['thal'].fillna(x,inplace=True)
#    age  sex  cp  trestbps  chol  fbs  restecg     thalach  exang  oldpeak  \
# 0   52    1   0     125.0   212    0      1.0  168.000000      0      1.0
# 1   53    1   0     140.0   203    1      0.0  155.000000      1      3.1
# 2   70    1   0     145.0   174    0      1.0  125.000000      1      2.6
# 3   61    1   0     148.0   203    0      1.0  149.102539      0      0.0
# ...

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# thalach above 150 wrong data ====>mean fill

# %%
x=df['thalach'].mean()
for i in df.index:
  if df.loc[i,'thalach'] > 150:
    df.loc[i,'thalach']=x

# %%
df.head(10)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg     thalach  exang  oldpeak  \
# 0   52    1   0     125.0   212    0      1.0  149.102539      0      1.0
# 1   53    1   0     140.0   203    1      0.0  149.102539      1      3.1
# 2   70    1   0     145.0   174    0      1.0  125.000000      1      2.6
# 3   61    1   0     148.0   203    0      1.0  149.102539      0      0.0
# 4   62    0   0     138.0   294    1      1.0  106.000000      0      1.9
# 5   58    0   0     100.0   248    0      0.0  122.000000      0      1.0
# 6   58    1   0     114.0   318    0      2.0  140.000000      0      4.4
# 7   55    1   0     160.0   289    0      0.0  145.000000      1      0.8
# 8   46    1   0     120.0   249    0      0.0  144.000000      0      0.8
# 9   54    1   0     122.0   286    0      0.0  116.000000      1      3.2
#
#    slope   ca  thal  target
# 0      2  2.0   3.0       0
# 1      0  0.0   3.0       0
# 2      0  0.0   3.0       0
# 3      2  1.0   3.0       0
# ...
