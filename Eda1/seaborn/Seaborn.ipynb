# %%
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.shape
# Out:
# (244, 7)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# # **Co-relation**

# %%
corrr=df.corr(numeric_only=True)

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %% [markdown]
# # **Joint Plot**

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='total_bill',y='size',data=df)

# %% [markdown]
# # **Pair PLot**
#
# same coloumn will be histogram

# %%
sns.pairplot(df,hue='day') # use hue='coloumn' for a categorisation

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# # **Count Plot**

# %%
df['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
sns.countplot(df,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(df,x='time')
# Out:
# <Axes: xlabel='time', ylabel='count'>

# %%
sns.countplot(df,x=df['day'],hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='count'>

# %%
sns.countplot(df,x='smoker',color='r',hue='sex')
# Out:
# /tmp/ipykernel_712/3818653719.py:1: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:r'` for the same effect.
#
#   sns.countplot(df,x='smoker',color='r',hue='sex')
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# # **Bar Chart**

# %%
sns.barplot(x='day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # **Box Plot**
#
# to identify outliers (wrong information on dataset)

# %%
sns.boxplot(y=df['total_bill'],data=df,color='c')
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(y=df['size'],data=df,color='c')
# Out:
# <Axes: ylabel='size'>

# %%
df['size'].mean()
# Out:
# np.float64(2.4595744680851066)

# %%
df.loc[df['size']>4]=df['size'].mode()[0]

# %%
sns.boxplot(y=df['size'],data=df,color='c')
# Out:
# <Axes: ylabel='size'>
