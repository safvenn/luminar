# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ## **KNN ALGORITHMS**

# %% [markdown]
# ## Simple Data set

# %%
x=[7,7,3,1]
y=[7,4,4,4]
target=['BAD','BAD','GOOD','GOOD']

features=list(zip(x,y))  ## we use zip() for combining the both values like [(7,7),(7,4),(3,4),(1,4)]
features
# Out:
# [(7, 7), (7, 4), (3, 4), (1, 4)]

# %%
model=KNeighborsClassifier(n_neighbors=3) # create a variable callled model for our ml model usiing KNeighborClassifier object , in KNeighborclassifier we must give N_neighbors , if we dont give it takes 5 as default value
model.fit(features,target) ## then we train our model with input feaatures and out put features by 'model.fit(in,out)' .After all we complrtrly build our model usiing KNN
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
print(model.predict([[3,7]])) # we use 'model.predict([[]])' for predict using our model by giving values
# Out:
# ['GOOD']

# %% [markdown]
# ## Using DATA SETS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/diabetes.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_446/2245693577.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/diabetes.csv")
#
# /usr/local/lib/python3.13/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df.shape

# %%
df.columns

# %%
df.head(5)

# %%
df.tail(5)

# %%
df.isna().sum()

# %%
df.duplicated().sum()

# %%
df.dtypes

# %%
df.value_counts()

# %%
outcome=df['Outcome'].value_counts()

plt.bar(outcome.index,outcome.values)
plt.xticks([0,1])

# %% [markdown]
# #Split features
#
# split coopumns into input and out put features

# %%
x=df.iloc[:,:-1].values

# %%
y=df.iloc[:,-1].values

# %% [markdown]
# ## Train data and test data
#
# train_test_split ===> 4 Variables
#
# x
# y
#
# (input_train,input_test_data)
# (output_train,output_test_data)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1) #random_state = 42,1,0 this gives best performance

# %%
x_train

# %% [markdown]
# ##**Scaling / Normalisation**
#
# make all input features in a same range bcoz range of input features almost same , higher difference in the range may leads to false prediction.\
# **2 types of scalling**
#
#
# 1.   Standard Scalar
# 2.   min max scalar

# %% [markdown]
# ### **Standard scallar**
#
#
# ---
# *equation:-*
#
# *z=(x-u)/s*
#
# *x=input* \
# *u=mean* \
# *s=standard deviation*
#
# ---

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
print(x_train)

# %%
model=KNeighborsClassifier(n_neighbors=15)
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_test)
y_pred

# %%
y_test

# %% [markdown]
# ## **Confution Matrix**
#
# we evaluate our classification model by confution matrix.
# eg:- in this data set output have two class label (output category) so matrix is 2*2 matrix.
#
# technical terms in confution matrix.
#
# 1.TP (TRUE POSITIVE)  1 ===> 0
#
# 2.TN (TRUE NEGATIVE)  0 ===> 0
#
# 3.FP (FALSE POSITIVE) 0 ===> 1
#
# 4.FN (FALSE NEGATIVE) 1 ===> 0
#
#
#
# ---
# this evalution methods are works by confution matrix:-
#
# 1.accuracy score \
# 2.recall \
# 3.precitiion \
# 4.f1 score

# %%
#to print confution matrix (not needed)
from sklearn.metrics import confusion_matrix
cm= confusion_matrix(y_test,y_pred)
cm

# %% [markdown]
# ###**1. Accuracy score**
#
# *equation = tp+tn/(tp+tn+fp+fn)*

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,y_pred)
score

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

for k in range(1, 21):
    model = KNeighborsClassifier(n_neighbors=k)
    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    print(f"K={k}, Accuracy={accuracy_score(y_test, y_pred):.3f}")
